# %%
# 5. In a new Code block, write a function that takes a list of strings and returns True if one of the 
# strings is "coconut" (in lower case), or False otherwise. Include code outside the function that 
# shows that the function works correctly.
# Fifth commit. 

def check_for_coconut(item_list):
    # Check if the exact string "coconut" exists in the list
    if "coconut" in item_list:
        return True
    else:
        return False

# --- Testing the code ---
list_with_coconut = ["apple", "banana", "coconut", "date"]
list_without_coconut = ["car", "bus", "train"]

# This should print True
print(f"List 1 has coconut? {check_for_coconut(list_with_coconut)}")

# This should print False
print(f"List 2 has coconut? {check_for_coconut(list_without_coconut)}")

# %%
# 6. In a new Code block, write a program that prompts the user to enter integers until an empty input 
# is given. The program should display how many of the numbers were even.
# Sixth commit.

# Start the counter at zero
count = 0

print("Type numbers. Press Enter on an empty line to stop.")

while True:
    text = input("Enter number: ")

    # Stop if the user just hits Enter
    if text == "":
        break

    # Convert text to a number
    number = int(text)

    # If the remainder when divided by 2 is 0, it's Even
    if number % 2 == 0:
        count = count + 1

print("You entered", count, "even numbers.")

# %%
# 7

text = input("Enter a string: ")

if text == text[::-1]:
    print("The string is a palindrome.")
else:
    print("The string is not a palindrome.")




# 8

def find_max(numbers):
    return max(numbers)

# Demonstration
nums = [3, 7, 2, 9, 5]
print(find_max(nums))


#9

number = int(input("Enter an integer: "))

# logical 'and' checks if both conditions are true
if number % 3 == 0 and number % 7 == 0:
    print("Divisible by both 3 and 7.")
else:
    print("Not divisible by both.")


#10


strings = []

while True:
    s = input("Enter a string: ")
    if s == "":
        break
    strings.append(s)

print("Number of unique strings:", len(set(strings)))



# 11

num = int(input("Enter an integer: "))

if num % 2 == 0:
    print("The number is even.")
else:
    print("The number is odd.")
